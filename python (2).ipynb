# %% [markdown]
# 1. What is the difference between interpreted and compiled languages
#
#  compiled languuager translate the entire program before execution while interpreted languages translate andexecute code line by line
#
# 2. What is exception handling in Python
#
#  allows you to gracefully manage erros that occur during program exection, preventing crashes and enabling more robust code
#
# 3. What is the purpose of the finally block in exception handling
#
#  it is used to execute important code such as closing resoueces regardless of whether an exception is thrown or not
#
# 4. What is logging in Python
#
#  a built -in module that allows youu to track events debug issues and monitor the heath of your applications by recording messades with different severity levels (like debug info warning error critical ) to files or other destinations
#
#  5.What is the significance of the __del__ method in Python0
#
#   used to delete object references (unbind name from objects )and remove elements from contaonaries freeing up memory resources and preventing accidental use of variable
#
# 6. What is the difference between import and from ... import in Python
#
#  in general you should use the import statement when you need to use many attribuutes from a module or when the module name is short and easy to remember you should use the from statement when you only need to use a few attributes from a module or when the module name is lond and hard to remember
#
# 7. How can you handle multiple exceptions in Python
#
#  you can handle multiple exceptions by using multiple except blocks each catching a specific type of exception or by using a single except block with a tuple of exception types
#
# 8. What is the purpose of the with statement when handling files in Python
#
#    the with statement in python file handling ensures that a file is automaticallly closed after its operations are complete even if arrers occur making your code cleaner and more robust
#
# 9. What is the difference between multithreading and multiprocessing
#
#  multithreading invoves runing multiple threads with in a single process while multiprocessing involves running multiple processes independently on differnt cores each with its own memory space
#
# 10. What are the advantages of using logging in a program
#
#  lonning helps protect from an unexpected forest fire and saves variouus wildife living in the forest
#
#  11. What is memory management in Python
#
#   the automated process of allocating and deallocatingmemory for objects handled primarily through reference counting andgarbage collection to ensure efficient memory usage and prevent leaks
#
# 12. What are the basic steps involved in exception handling in Python
#
#    exception handling involeves using try except ,else ,and finally block to manage errors and ensure your program continues running gracefully
#
# 13. Why is memory management important in Python
#
#   this memory management manages python objects and data structures
#
# 14.What is the role of try and except in exception handling
#
#  the try block lets you test a block of code for errors the except block lets you handle the error
#
#  15. How does Python's garbage collection system work
#
#   a reference couning approach each object in python has a reference count ,which shows how many other objects are referencing it there are on longer when its reference count approaches zero enabling safe deallocation
#
# 16. What is the purpose of the else block in exception handling
#
#  lets yo execte code there is on error
#
# 17. What are the common logging levels in Python
#
#  there are six levels for logging in python each level is associated with an integer tht indicates the log severity :NOTSET=0'DEBUG =10, INFO=20, WARN=30, ERROR=40 ,and CRITICAL =50.
#
#  18.What is the difference between os.fork() and multiprocessing in Python
#
#  creates a copy of the process that has called it frok is the default on linux (it isn't avallable on windows)
#
# 19. What is the importance of closing a file in Python
#
#  you've learned why it's important to close files in python because files are limited resources managed by the operating system making sure files are closed after use will protect against hard to debug issues like running out of file handles or experirencing corrupted data
#
#
# 20. What is the difference between file.read() and file.readline() in Python
#
#  the 'read()'method is used to read a specified number of charactes from a file or input stream while the 'readling'() method is used to read a single line from a file or input stream
#
# 21. What is the logging module in Python used for
#
#  logging module to log messager to a file to the python logging console or to a custume logging handler
# 22.What is the os module in Python used for in file handling
#
#  interacting with the operating system like creating files and directories management of files and directories input output environment variable process management etc
#
# 23. What are the challenges associated with memory management in Python0
#
#    potential memory leaks due to cirular references performance overhead from garbage collection and the need for memory profiling to identify inefficencies especially when dealing with large datasets or complex applications
#
# 24. How do you raise an exception manually in Python
#
#  as a python developer you can choose to throw an exception if a condition occurs to throw (or raise) an exception ,use the raise keyword
#
# 25. Why is it important to use multithreading in certain applications?
#
#   enable efficient resource utllization improves performance enhances respondiveness and allows for better scalability by breaking down tasks into smaller concurrent threads
